# %% [markdown]
# <h1 align="center"> Exploratory Data Analysis</h1>
#
# **EDA**: it means exploration of data (you have to explore data more ) <br>**CRIPS-DM** Cross-Industry Standard Process for Data Mining.
#
# ![CRISP-DM with KI Integration](./CRISP-DM-.png)<br>
# *Any of the ML problem statement these are the methods that one should follow while any doing any data science project or problem statement.*<br>
# 1. Business Understading: Whenever some problem statements come first of all you have understand the business problem.<br>**For Instance:** *if you wanna predict to price of house, so you need to understand how the price prediction gonna help in increasing revenue.*
# 2. Data Understading: To understand the data you need to follow some method, and these methods comes under a broader umbrella i.e. **Exploratory Data Analysis**
# 3. Data Preparation: Here you will do Missing value treatment, Data encoding, Outlier detection and so on...
# 4. Modeling: here you are going to build ML model/ Algorithm.
# 5. Evaluation: Here you will check how your ML models preforming *eg,. it's good, bad, it's hit banchmark....*
# 6. Deployment: here you deploy your model on server for business use to business team. <br><br>
# ***This is journey of DS project***

# %% [markdown]
# **EDA** <br> *(1) Profile of data:* it include looks at no of rows, cols, data type, duplicate values....<br> *(2)Statistical based Analysis:* calculate five point summary, outlier, correlation, etc...<br> *(3) Graph based Analysis:* Scatter plot, Heatmap, pairplot, box plot etc...<br>
# <br>
# <b> <i> Once you understood the data well then -> select relevant features, convert to numerical i.e data preparation. </i></b><br><br>
# <h5>How to do EDA?</h5>
# There are 100's of features (f1,f2,f3,....f100), from these features/data to gain insights -> EDA. <br>
# 1. Uni-variate Analysis: To do EDA you can start with one feature first i.e. <b> Uni variat analysis.</b> to cite an example: let's you took one feature and make a dist plot of it.<br>
# 2. Bi-Variate Analysis: two features at a time <i>eg,. Scatterplot</i><br>
# 3. Multivariate Analysis: took multipule features at a time <i> eg,. Heatmap, pairplot....</i>
# <br><br><br>
# <b> To understand in depth i will do EDA on 7 datasets, which gives you real feel real world dataset. </b>

# %% [markdown]
# <h1> 1. EDA using Google Playstore dataset</h1>

# %%
#install libraries and load data
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
df = pd.read_csv("googleplaystore.csv")

# %% [markdown]
# <h2> (A) Data Preparation </h2>

# %%
df.columns #to check the columns of the dataset
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.head() #to check the first 5 rows of the dataset
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.tail() #to check the last 5 rows of the dataset
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
df.sample(2) #to check random 2 rows of the dataset
# Out:
#                                        App       Category  Rating Reviews  \
# 396                       Android Messages  COMMUNICATION     4.2  781810
# 4669  Remote For ATT U-verse TV - NOW FREE          TOOLS     2.5      20
#
#                     Size      Installs  Type Price Content Rating  \
# 396   Varies with device  100,000,000+  Free     0       Everyone
# 4669                 26M        5,000+  Free     0       Everyone
#
#              Genres    Last Updated         Current Ver         Android Ver
# 396   Communication  August 1, 2018  Varies with device  Varies with device
# 4669          Tools   July 25, 2018               6.1.5          4.2 and up

# %%
df.shape #to check the shape of the dataset
# Out:
# (10841, 13)

# %%
df.describe() #to check the statistical summary of the dataset, aslo called five point summary, it provides statistical information for nunerical data. 5 point summary includes count, mean, std, min, 25%, 50%, 75% and max.
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
# to check the statistical summary of the dataset for all columns, including categorical data, we can use the include parameter and set it to "all". This will provide statistical information for both numerical and categorical data.
df.describe(include="all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df.info() #to check the information of the dataset, it provides information about the data types, non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# <p> Note : here you may think about all the columns are object type except Rating column. why it so ? why rating column float and why install column is not,,, so we have to deep dive into each columns to understand, prepare the data. </p>

# %%
df.duplicated().sum() #to check the number of duplicate rows in the dataset
# Out:
# np.int64(483)

# %%
df= df.drop_duplicates() #to drop the duplicate rows from the dataset
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#checking again for duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.dtypes #to check the data types of the all columns in the dataset same as df.info()
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
# if you want to check one column at a time 
df['Content Rating'].dtype #to check the d ata type of the column 'Content Rating'
# Out:
# dtype('O')

# %%
df['Reviews'].dtype #to check the data type of the column 'Reviews'
# Out:
# dtype('O')

# %%
#let's check the values of the column 'Reviews'
df["Reviews"]
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10358, dtype: object

# %% [markdown]
# <p> Note: The Reviews colums it seems to be numerical values but why it is object type ?</p>

# %%
# let's check the unique values of the column 'Reviews' so may be there are some non-numeric values in the column 'Reviews' which is causing the data type to be object instead of numeric.
df["Reviews"].unique()
# we didn't find any non-numeric values in the column 'Reviews'.
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'],
#       shape=(6002,), dtype=object)

# %%
# It is possible that in Reviews column there might be a value which is a string and hence converting the whole column into object data type. 
# to understand this.
type("1") # this is a string value
# Out:
# str

# %%
"1".isnumeric() # this will check if the string value is numeric or not, it will return True if the string value is numeric and False if the string value is not numeric.
# Out:
# True

# %%
df.Reviews.str.isnumeric() # this will check if all the values in the column 'Reviews' are numeric or not, it will return a series of boolean values.
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 10836    True
# 10837    True
# 10838    True
# 10839    True
# 10840    True
# Name: Reviews, Length: 10358, dtype: bool

# %%
~df.Reviews.str.isnumeric() # this will return the values which are not numeric in the column 'Reviews', it will return a series of boolean values.
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Reviews, Length: 10358, dtype: bool

# %%
# to know the exact row which has non-numeric value in the column 'Reviews'
df[~df.Reviews.str.isnumeric()] # this will return the rows which have non-numeric values in the column 'Reviews'.
# we found that there is a value "3.0M" in the column 'Reviews' which is a non-numeric value, it is a string value and it is not numeric. due to this value the whole column 'Reviews' is of object data type instead of numeric data type.
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
#know how to solve this issue 
df_copy= df.copy() # to create a copy of the original dataframe, so that we can work on the copy of the dataframe and keep the original dataframe intact.
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#reseting the index of the dataframe, because after dropping the duplicate values  original index is still there.

df_copy.reset_index(drop=True, inplace=True) # to reset the index of the dataframe, drop=True will drop the old index and inplace=True will make the changes in the original dataframe.
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy[~df_copy.Reviews.str.isnumeric()]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
df_copy = df_copy.drop(df_copy.index[9990]) # dropping the non-numeric value

# %%
df_copy[~df_copy.Reviews.str.isnumeric()] # now we can see that there is no non-numeric value in the column 'Reviews' and all the values are numeric.
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df_copy['Reviews']=df_copy['Reviews'].astype(int) # to convert the data type of the column 'Reviews' to integer.

# %%
df_copy.info() # to check the information of the dataframe, now we can see that the data type of the column 'Reviews' is integer instead of object.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            10357 non-null  object
#  5   Installs        10357 non-null  object
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 1.1+ MB

# %%
df_copy.Reviews.dtype 
#now we can see that the data type of the column 'Reviews' is integer, which is a numeric data type.
# Out:
# dtype('int64')

# %%
df["Size"] # checking the vlues of the column 'Size'
# Out:
# 0                       19M
# 1                       14M
# 2                      8.7M
# 3                       25M
# 4                      2.8M
#                 ...
# 10836                   53M
# 10837                  3.6M
# 10838                  9.5M
# 10839    Varies with device
# 10840                   19M
# Name: Size, Length: 10358, dtype: object

# %%
df['Size'].unique() # checking unique values
# we can see some value kb and some M and one value is Varies with device.
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
# lets say one item is there, where value is 19M.
item = "19M"

# %%
# now if i wanna acess this particular M 
item [-1]
# Out:
# 'M'

# %%
 # 1mb = 1024 kb
 # so lets write a function to replace M with empty string and then convert it into float and then multiply it with 1024 to convert it into kb, and if the value is in kb then we will just convert it into float and return it, and if the value is Varies with device then we will return NaN. 
def size_process(item):
     if str(item)[-1] == "M":
        res = float(str(item).replace("M", ""))
        res = res*1024
        return res
     elif str(item)[-1] == "k":
        res = float(str(item).replace("k", ""))
        return res
     else:
        return str(np.nan)

# %%
size_process("19M") # to check the function is working or not, it should return 19456.0 because 19*1024=19456.0
# Out:
# 19456.0

# %%
#now we will apply this function to the column 'Size' to convert all the values in the column 'Size' to numeric values.
df_copy['Size'] = df_copy['Size'].apply(size_process)

# %%
df_copy['Size'].unique()
# Out:
# array([19456.0, 14336.0, 8908.8, 25600.0, 2867.2, 5734.4, 29696.0,
#        33792.0, 3174.4, 28672.0, 12288.0, 20480.0, 21504.0, 37888.0,
#        2764.8, 5632.0, 17408.0, 39936.0, 31744.0, 4300.8, 7168.0, 23552.0,
#        6144.0, 6246.4, 4710.4, 9420.8, 5324.8, 11264.0, 24576.0, 'nan',
#        9625.6, 15360.0, 10240.0, 1228.8, 26624.0, 8192.0, 8089.6, 57344.0,
#        58368.0, 35840.0, 55296.0, 201.0, 3686.4, 5836.8, 8806.4, 2457.6,
#        27648.0, 2560.0, 16384.0, 3481.6, 9113.6, 3993.6, 2969.6, 38912.0,
#        32768.0, 5529.6, 18432.0, 1126.4, 2252.8, 4608.0, 10035.2, 53248.0,
#        9216.0, 6860.8, 30720.0, 2662.4, 7270.4, 3788.8, 22528.0, 7577.6,
#        6553.6, 3276.8, 8396.8, 10137.6, 5017.6, 9728.0, 5120.0, 6041.6,
#        13312.0, 74752.0, 6963.2, 3584.0, 4096.0, 2355.2, 7372.8, 2150.4,
#        43008.0, 7475.2, 9318.4, 56320.0, 23.0, 6656.0, 1536.0, 7680.0,
#        52224.0, 41984.0, 49152.0, 8704.0, 47104.0, 8499.2, 4403.2, 4812.8,
# ...

# %%
df_copy['Size'].dtypes
# Out:
# dtype('O')

# %%
#convert data type to float
df_copy['Size'] = df_copy['Size'].astype(float)
df_copy['Size'].dtypes
# Out:
# dtype('float64')

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  object
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df_copy["Installs"]
# Out:
# 0            10,000+
# 1           500,000+
# 2         5,000,000+
# 3        50,000,000+
# 4           100,000+
#             ...
# 10353         5,000+
# 10354           100+
# 10355         1,000+
# 10356         1,000+
# 10357    10,000,000+
# Name: Installs, Length: 10357, dtype: object

# %%
df_copy['Installs'] = df_copy['Installs'].str.replace("+", "").str.replace(",", "")# to remove the + and , from the values in the column 'Installs' so that we can convert the data type of the column 'Installs' to numeric data type.

# %%
df_copy['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10353        5000
# 10354         100
# 10355        1000
# 10356        1000
# 10357    10000000
# Name: Installs, Length: 10357, dtype: object

# %%
#df_copy['Installs'] = df_copy['Installs'].astype(int) # to convert the data type of the column 'Installs' to integer data type.

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  object
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  object
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(2), int64(1), object(10)
# memory usage: 1.1+ MB

# %%
df_copy.Price.unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
char_to_remove = ["+","$",","]# to remove the +, $ and , from the values in the column 'Price' so that we can convert the data type of the column 'Price' to numeric data type.
cols_to_remove = ["Installs", "Price"] # to specify the columns from which we want to remove the characters.
for char in char_to_remove:
    for col in cols_to_remove:
        df_copy[col] = df_copy[col].str.replace(char,"")# to remove the characters from the specified columns.

# %%
df_copy.Price.unique()
# Out:
# array(['0', '4.99', '3.99', '6.99', '1.49', '2.99', '7.99', '5.99',
#        '3.49', '1.99', '9.99', '7.49', '0.99', '9.00', '5.49', '10.00',
#        '24.99', '11.99', '79.99', '16.99', '14.99', '1.00', '29.99',
#        '12.99', '2.49', '10.99', '1.50', '19.99', '15.99', '33.99',
#        '74.99', '39.99', '3.95', '4.49', '1.70', '8.99', '2.00', '3.88',
#        '25.99', '399.99', '17.99', '400.00', '3.02', '1.76', '4.84',
#        '4.77', '1.61', '2.50', '1.59', '6.49', '1.29', '5.00', '13.99',
#        '299.99', '379.99', '37.99', '18.99', '389.99', '19.90', '8.49',
#        '1.75', '14.00', '4.85', '46.99', '109.99', '154.99', '3.08',
#        '2.59', '4.80', '1.96', '19.40', '3.90', '4.59', '15.46', '3.04',
#        '4.29', '2.60', '3.28', '4.60', '28.99', '2.95', '2.90', '1.97',
#        '200.00', '89.99', '2.56', '30.99', '3.61', '394.99', '1.26',
#        '1.20', '1.04'], dtype=object)

# %%
df_copy["Installs"] = df_copy["Installs"].astype(int) # to convert the data type of the column 'Installs' to integer data type.
df_copy["Price"] = df_copy["Price"].astype(float) # to convert the data type of the column 'Price' to float data type.
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10357 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10357 non-null  object
#  1   Category        10357 non-null  object
#  2   Rating          8892 non-null   float64
#  3   Reviews         10357 non-null  int64
#  4   Size            8831 non-null   float64
#  5   Installs        10357 non-null  int64
#  6   Type            10356 non-null  object
#  7   Price           10357 non-null  float64
#  8   Content Rating  10357 non-null  object
#  9   Genres          10357 non-null  object
#  10  Last Updated    10357 non-null  object
#  11  Current Ver     10349 non-null  object
#  12  Android Ver     10355 non-null  object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1.1+ MB

# %%
df_copy["Last Updated"] # to check the values of the column 'Last Updated'
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10353       July 25, 2017
# 10354        July 6, 2018
# 10355    January 20, 2017
# 10356    January 19, 2015
# 10357       July 25, 2018
# Name: Last Updated, Length: 10357, dtype: object

# %%
df_copy["Last Updated"] = pd.to_datetime(df_copy["Last Updated"]) # to convert the data type of the column 'Last Updated' to datetime data type.
df_copy["Last Updated"]
# Out:
# 0       2018-01-07
# 1       2018-01-15
# 2       2018-08-01
# 3       2018-06-08
# 4       2018-06-20
#            ...
# 10353   2017-07-25
# 10354   2018-07-06
# 10355   2017-01-20
# 10356   2015-01-19
# 10357   2018-07-25
# Name: Last Updated, Length: 10357, dtype: datetime64[ns]

# %%
df_copy["day"]=df_copy["Last Updated"].dt.day # to extract the day from the column 'Last Updated'
df_copy["month"]=df_copy["Last Updated"].dt.month # to extract the month from the column 'Last Updated'
df_copy["year"]=df_copy["Last Updated"].dt.year # to extract the year from the column 'Last Updated'
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.dtypes
# Out:
# App                       object
# Category                  object
# Rating                   float64
# Reviews                    int64
# Size                     float64
# Installs                   int64
# Type                      object
# Price                    float64
# Content Rating            object
# Genres                    object
# Last Updated      datetime64[ns]
# Current Ver               object
# Android Ver               object
# day                        int32
# month                      int32
# year                       int32
# dtype: object

# %%
df_copy.drop("Last Updated", axis=1, inplace=True) # to drop the column 'Last Updated' from the dataframe, axis=1 will drop the column and inplace=True will make the changes in the original dataframe.

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy["Android Ver"].unique() # to check the unique values of the column 'Android Version'
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
#remove the "and up "
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("and up", "") # to remove the "and up " from the values in the column 'Android Version' so that we can convert the data type of the column 'Android Version' to numeric data type.
df_copy["Android Ver"].unique() # to check the unique values of the column
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3',
#        'Varieswithdevice', '2.2', '5.0', '6.0', '1.6', '1.5', '2.1',
#        '7.0', '5.1', '4.3', '4.0.37.1.1', '2.0', '3.2', '7.1', '7.07.1.1',
#        '8.0', '5.08.0', '3.1', '2.0.1', '4.17.1.1', '5.06.0', '1.0',
#        '2.27.1.1', '5.07.1.1'], dtype=object)

# %%
#remove "varies with device"
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("Varieswithdevice", "") # to remove the "Varies with device" from the values in the column 'Android Version' so that we can convert the data type of the column 'Android Version' to numeric data type.
df_copy["Android Ver"].unique() # to check the unique values of the column
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', '',
#        '2.2', '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3',
#        '4.0.37.1.1', '2.0', '3.2', '7.1', '7.07.1.1', '8.0', '5.08.0',
#        '3.1', '2.0.1', '4.17.1.1', '5.06.0', '1.0', '2.27.1.1',
#        '5.07.1.1'], dtype=object)

# %%
# remove "W "
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("W", "") # to remove the "W " from the values in the column 'Android Version' so that we can convert the data type of the column 'Android Version' to numeric data type.
df_copy["Android Ver"].unique() # to check the unique values of the column
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', '',
#        '2.2', '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3',
#        '4.0.37.1.1', '2.0', '3.2', '7.1', '7.07.1.1', '8.0', '5.08.0',
#        '3.1', '2.0.1', '4.17.1.1', '5.06.0', '1.0', '2.27.1.1',
#        '5.07.1.1'], dtype=object)

# %%
# remove "nan"
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("nan", "") # to remove the "nan" from the values in the column 'Android Version' so that we can convert the data type of the column 'Android Version' to numeric data type.
df_copy["Android Ver"].unique() # to check the unique values of the column
df_copy["Android Ver"] = df_copy["Android Ver"].replace("", pd.NA)
df_copy.dropna(subset=["Android Ver"], inplace=True)

df_copy["Android Ver"].unique()
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', '2.2',
#        '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3',
#        '4.0.37.1.1', '2.0', '3.2', '7.1', '7.07.1.1', '8.0', '5.08.0',
#        '3.1', '2.0.1', '4.17.1.1', '5.06.0', '1.0', '2.27.1.1',
#        '5.07.1.1'], dtype=object)

# %%
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace(" ", "") # to remove the " " from the values in the column 'Android Version' so that we can convert the data type of the column 'Android Version' to numeric data type.
df_copy["Android Ver"] = df_copy["Android Ver"].str.replace("-", "")
df_copy["Android Ver"].unique()
# Out:
# array(['4.0.3', '4.2', '4.4', '2.3', '3.0', '4.1', '4.0', '2.3.3', '2.2',
#        '5.0', '6.0', '1.6', '1.5', '2.1', '7.0', '5.1', '4.3',
#        '4.0.37.1.1', '2.0', '3.2', '7.1', '7.07.1.1', '8.0', '5.08.0',
#        '3.1', '2.0.1', '4.17.1.1', '5.06.0', '1.0', '2.27.1.1',
#        '5.07.1.1'], dtype=object)

# %%
# let's look another column.
df_copy.App
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
#                                ...
# 10351                                        FR Calculator
# 10352                                             FR Forms
# 10353                                     Sya9a Maroc - FR
# 10354                     Fr. Mike Schmitz Audio Teachings
# 10355                               Parkinson Exercices FR
# Name: App, Length: 8667, dtype: object

# %%
df[df.duplicated("App")]
# Out:
#                                             App       Category  Rating  \
# 285                Quick PDF Scanner + OCR FREE       BUSINESS     4.2
# 293      OfficeSuite : Free Office + PDF Editor       BUSINESS     4.3
# 294                                       Slack       BUSINESS     4.4
# 382    Messenger – Text and Video Chat for Free  COMMUNICATION     4.0
# 383               imo free video calls and chat  COMMUNICATION     4.3
# ...                                         ...            ...     ...
# 10647                         Motorola FM Radio  VIDEO_PLAYERS     3.9
# 10715                        FarmersOnly Dating         DATING     3.0
# 10720        Firefox Focus: The privacy browser  COMMUNICATION     4.4
# 10730                               FP Notebook        MEDICAL     4.5
# 10753            Slickdeals: Coupons & Shopping       SHOPPING     4.5
#
#         Reviews                Size        Installs  Type Price  \
# ...

# %%
df_copy = df_copy.drop_duplicates(subset = ["App"], keep = "first") # to drop the duplicate values from the column 'App', subset=["App"] will specify the column from which we want to drop the duplicate values, keep="first" will keep the first occurrence of the duplicate values and drop the rest.

# %%
df_copy[df_copy.duplicated("App")]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Current Ver, Android Ver, day, month, year]
# Index: []

# %%
df_copy
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10351                                      FR Calculator          FAMILY
# 10352                                           FR Forms        BUSINESS
# 10353                                   Sya9a Maroc - FR          FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10355                             Parkinson Exercices FR         MEDICAL
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# <h2> (B) Exploratory Data Analysis </h2>

# %%
# categorical features
categorical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype =='O']

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
categorical_features
# Out:
# ['App',
#  'Category',
#  'Type',
#  'Content Rating',
#  'Genres',
#  'Current Ver',
#  'Android Ver']

# %%
# numerical features
numerical_features = [feature for feature in df_copy.columns if df_copy[feature].dtype !='O']
numerical_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
df_copy[categorical_features]
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10351                                      FR Calculator          FAMILY
# 10352                                           FR Forms        BUSINESS
# 10353                                   Sya9a Maroc - FR          FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10355                             Parkinson Exercices FR         MEDICAL
#
#        Type Content Rating                     Genres         Current Ver  \
# ...

# %% [markdown]
# <h4>let's Analyse data - categorical features - using different types of plots such as frequency plot, bar chart, pie chart....and for numerical features -histogram, displot,box, line ......</h4>

# %%
#1. categorical features analysis
df_copy["Type"].value_counts(normalize=True) # to check the value counts of the column 'Type', it will return the count of each unique value in the column 'Type'.
# Out:
# Type
# Free    0.920042
# Paid    0.079958
# Name: proportion, dtype: float64

# %%
# lets do the same for all columns 
for col in categorical_features:
    print(f"{col} : {df_copy[col].value_counts(normalize=True)}") # to check the value counts of all the categorical columns, it will return the count of each unique value in each categorical column.}
# Out:
# App : App
# Photo Editor & Candy Camera & Grid & ScrapBook    0.000115
# Comboios de Portugal                              0.000115
# Talking Pictures: Autism, CP                      0.000115
# CP ToolBox                                        0.000115
# CP-Care Mobile                                    0.000115
#                                                     ...
# O-Level Past Papers & Solution (up to 2017)       0.000115
# Pixlr-o-matic                                     0.000115
# Verdad o Reto                                     0.000115
# O Launcher                                        0.000115
# Parkinson Exercices FR                            0.000115
# Name: proportion, Length: 8667, dtype: float64
# Category : Category
# FAMILY                 0.204223
# GAME                   0.105688
# TOOLS                  0.084920
# BUSINESS               0.044768
# MEDICAL                0.043037
# PERSONALIZATION        0.040152
# LIFESTYLE              0.039229
# ...

# %%
df_copy["Android Ver"].value_counts(normalize=True)
# Out:
# Android Ver
# 4.1           0.254067
# 4.0.3         0.160955
# 4.0           0.148264
# 4.4           0.095650
# 2.3           0.071074
# 5.0           0.059075
# 4.2           0.042921
# 2.3.3         0.031499
# 2.2           0.027576
# 3.0           0.026653
# 4.3           0.025499
# 2.1           0.015346
# 1.6           0.013384
# 6.0           0.006231
# 7.0           0.004846
# 3.2           0.004154
# 2.0           0.003692
# 5.1           0.002538
# 1.5           0.002308
# 3.1           0.001154
# 2.0.1         0.000808
# 8.0           0.000692
# 7.1           0.000346
# 4.0.37.1.1    0.000231
# 5.08.0        0.000231
# 1.0           0.000231
# 7.07.1.1      0.000115
# 4.17.1.1      0.000115
# 5.06.0        0.000115
# 2.27.1.1      0.000115
# 5.07.1.1      0.000115
# Name: proportion, dtype: float64

# %%
df_copy["Type"].value_counts(normalize=True)*100
# Out:
# Type
# Free    92.004154
# Paid     7.995846
# Name: proportion, dtype: float64

# %%
# lets make a plot 
sns.countplot(x=df_copy["Type"]) # to make a count plot of the column 'Type', it will show the count of each unique value in the column 'Type' in the form of a bar plot.
# adding title and labels to the plot and different colors to the bars
sns.countplot(x=df_copy["Type"], palette="Set2") # to make a count plot of the column 'Type', it will show the count of each unique value in the column 'Type' in the form of a bar plot.
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
# now plot for content rating
sns.countplot(x=df_copy["Content Rating"], palette="Set2") # to make a count plot of the column 'Content Rating', it will show the count of each unique value in the column 'Content Rating' in the form of a bar plot.
# Out:
# <Axes: xlabel='Content Rating', ylabel='count'>

# %%
# lets move to numerical features analysis
numerical_features
# Out:
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price', 'day', 'month', 'year']

# %%
sns.displot(df_copy["Price"], kde=True) # to make a distribution plot of the column 'Price', it will show the distribution of the values in the column 'Price' in the form of a histogram and a kernel density estimate (KDE) plot.

# %%
sns.displot(df_copy["Rating"], kde=True)

# %%
sns.kdeplot(df_copy["Rating"], shade=True)
# Out:
# <Axes: xlabel='Rating', ylabel='Density'>

# %%
plt.figure(figsize=(20,15))
catogory = [ "Content Rating", "Type"]
for i in range(0,len(catogory)):
    plt.subplot(1,2,i+1)
    
    sns.countplot(x=df_copy[catogory[i]], palette="Set2")
    plt.xlabel(catogory[i])
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.ylabel("Count")
    plt.title(f"Count plot of {catogory[i]}")

# %%
df_copy
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10351                                      FR Calculator          FAMILY
# 10352                                           FR Forms        BUSINESS
# 10353                                   Sya9a Maroc - FR          FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10355                             Parkinson Exercices FR         MEDICAL
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %% [markdown]
# <h4> Q. Which category is the most popular category in the app.</h4>

# %%
#lets make a pie chart
df_copy["Category"].value_counts().plot.pie(y  = df["Category"], figsize=(12,12), autopct="%1.1f%%") # to make a pie chart of the column 'Category', it will show the count of each unique value in the column 'Category' in the form of a pie chart, autopct="%1.1f%%" will show the percentage of each unique value in the pie chart.
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# insights -- the most popular category as Family with 20.4% of the share.

# %% [markdown]
# <h4>Q. what is top 10 most popular category</h4>

# %%
cat = df_copy["Category"].value_counts()[:10] # to check the top 10 unique values in the column 'Category' and their counts.
cat
# Out:
# Category
# FAMILY             1770
# GAME                916
# TOOLS               736
# BUSINESS            388
# MEDICAL             373
# PERSONALIZATION     348
# LIFESTYLE           340
# FINANCE             304
# PRODUCTIVITY        302
# SPORTS              293
# Name: count, dtype: int64

# %%
category = cat.reset_index() # to reset the index of the series 'cat' and convert it into a dataframe, it will create a new column 'index' which will have the unique values of the column 'Category' and the column 'Category' will have the counts of each unique value in the column 'Category'.
category.columns = ["Group", "Count"] # to rename the columns of the dataframe 'category', the first column will be renamed as 'Group' and the second column will be renamed as 'Count'.
category
# Out:
#              Group  Count
# 0           FAMILY   1770
# 1             GAME    916
# 2            TOOLS    736
# 3         BUSINESS    388
# 4          MEDICAL    373
# 5  PERSONALIZATION    348
# 6        LIFESTYLE    340
# 7          FINANCE    304
# 8     PRODUCTIVITY    302
# 9           SPORTS    293

# %%
sns.barplot(x=category["Group"], y=category["Count"], palette="Set2") # to make a bar plot of the dataframe 'category', it will show the count of each unique value in the column 'Category' in the form of a bar plot, x=category["Group"] will specify the x-axis and y=category["Count"] will specify the y-axis.
plt.xticks(rotation=45) # to rotate the x-axis labels by 45 degrees, so that they are more readable.
plt.xlabel("Category") # to set the x-axis label as "Category"
plt.ylabel("Count") # to set the y-axis label as "Count"
plt.title("Count plot of Category") # to set the title of the plot as "Count plot of Category"
plt.tight_layout() # to adjust the padding between and around subplots to make the plot look better.

# %% [markdown]
# <h4> Q. which category has the highest installation</h4>

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
df_copy.groupby(["Category"])["Installs"].sum().sort_values(ascending=False).reset_index()        # to group the dataframe by the column 'Category' and then sum the values in the column 'Installs' for each unique value in the column 'Category', and then sort the values in descending order.
# Out:
#                Category     Installs
# 0                  GAME  13087064264
# 1                FAMILY   4005407335
# 2                 TOOLS   2996154815
# 3         COMMUNICATION   2653153051
# 4           PHOTOGRAPHY   2036997655
# 5          PRODUCTIVITY   1748513744
# 6    NEWS_AND_MAGAZINES   1182106760
# 7         VIDEO_PLAYERS    964677720
# 8                SPORTS    892454498
# 9       PERSONALIZATION    855068772
# 10             SHOPPING    830248785
# 11   HEALTH_AND_FITNESS    766561912
# 12               SOCIAL    673765902
# 13        ENTERTAINMENT    623860000
# 14     TRAVEL_AND_LOCAL    463666146
# 15             BUSINESS    400432760
# 16            LIFESTYLE    391902439
# 17              FINANCE    256632634
# 18  MAPS_AND_NAVIGATION    184079890
# 19            EDUCATION    177402000
# 20       FOOD_AND_DRINK    139588740
# 21  BOOKS_AND_REFERENCE    134962576
# 22              WEATHER    129400020
# 23       ART_AND_DESIGN    104338100
# ...

# %%
sns.boxplot (df_copy["Rating"])
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.boxplot(x = "Installs", y="Rating", data=df_copy)
colors = ["red", "blue", "green", "orange", "purple", "cyan", "magenta", "yellow", "brown", "pink"]
sns.boxplot(x = "Installs", y="Rating", data=df_copy, palette=colors)
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>

# %% [markdown]
# <h4> Q. what are top 5 installed category apps in each type</h4>

# %%
df_copy
# Out:
#                                                      App        Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN
# 1                                    Coloring book moana  ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint  ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN
# ...                                                  ...             ...
# 10351                                      FR Calculator          FAMILY
# 10352                                           FR Forms        BUSINESS
# 10353                                   Sya9a Maroc - FR          FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings          FAMILY
# 10355                             Parkinson Exercices FR         MEDICAL
#
#        Rating  Reviews     Size  Installs  Type  Price Content Rating  \
# ...

# %%
top_5_apps = (
    df_copy[
        (df_copy["Category"] == "GAME")
    ]
    .sort_values(by="Installs", ascending=False)
    [["App", "Category", "Type", "Installs"]]
    .head(5)
)

top_5_apps
# Out:
#                    App Category  Type    Installs
# 1447    Subway Surfers     GAME  Free  1000000000
# 1448  Candy Crush Saga     GAME  Free   500000000
# 1513    My Talking Tom     GAME  Free   500000000
# 1454      Temple Run 2     GAME  Free   500000000
# 1455               Pou     GAME  Free   500000000

# %%
#groupby on category and type column with aggregation on Installs columns
applications =df_copy.groupby(["App", "Type"])["Installs"].sum().sort_values(ascending=False).reset_index()   
applications # to group the dataframe by the columns 'Category' and 'Type' and then sum the values in the column 'Installs' for each unique combination of values in the columns 'Category' and 'Type', and then sort the values in descending order.
applications.head(5) # to check the top 5 rows of the dataframe 'applications', it will show the top 5 apps with their type and total installs.
# Out:
#                                      App  Type    Installs
# 0                         Subway Surfers  Free  1000000000
# 1                            Google News  Free  1000000000
# 2  Google Duo - High Quality Video Calls  Free   500000000
# 3                         My Talking Tom  Free   500000000
# 4                                    Pou  Free   500000000

# %%
# make a bar plot of the top 5 installed apps
sns.barplot(x=top_5_apps["App"], y=top_5_apps["Installs"], palette="Set2") 
plt.xticks(rotation=45) 
plt.xlabel("App") 
plt.ylabel("Installs") 
plt.title("Top 5 Installed Apps")
# Out:
# Text(0.5, 1.0, 'Top 5 Installed Apps')

# %% [markdown]
# <h4>Q. which category app users are reviewing the most? Social Facebook</h4>

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Current Ver', 'Android Ver',
#        'day', 'month', 'year'],
#       dtype='object')

# %%
# top most reviewed apps by category 
top_5_reviewed_apps_by_category = (
    df_copy
    .sort_values(["Category", "Reviews"], ascending=[True, False])
    .groupby("Category").head(5)
    [["Category", "App", "Reviews"]]
    .reset_index(drop=True)
)

top_5_reviewed_apps_by_category.head(5)
# Out:
#          Category                                                App  Reviews
# 0  ART_AND_DESIGN                                       ibis Paint X   224399
# 1  ART_AND_DESIGN                              Sketch - Draw & Paint   215644
# 2  ART_AND_DESIGN                      FlipaClip - Cartoon animation   194216
# 3  ART_AND_DESIGN  Canva: Poster, banner, card maker & graphic de...   174531
# 4  ART_AND_DESIGN  U Launcher Lite – FREE Live Cool Themes, Hide ...    87510

# %%
#groupby category and app, aggregated sum on reviews
top_reviewed_apps_by_category = (
    df_copy.groupby(["Category", "App"])["Reviews"].sum().sort_values(ascending=False).reset_index()
)
top_reviewed_apps_by_category.head(5)
# Out:
#         Category                                          App   Reviews
# 0           GAME                               Clash of Clans  44891723
# 1           GAME                               Subway Surfers  27722264
# 2           GAME                                 Clash Royale  23133508
# 3           GAME                             Candy Crush Saga  22426677
# 4  COMMUNICATION  UC Browser - Fast Download Private & Secure  17712922

# %%
sns.barplot(x=top_reviewed_apps_by_category["App"].head(5), y=top_reviewed_apps_by_category["Reviews"].head(5), palette="Set1")
plt.xticks(rotation = 80)
plt.xlabel("App")
plt.ylabel("Reviews")
plt.title("Top Reviewed Apps by Category")
# Out:
# Text(0.5, 1.0, 'Top Reviewed Apps by Category')

# %% [markdown]
# insights - the top reviewed app is clash fo clans of category game
